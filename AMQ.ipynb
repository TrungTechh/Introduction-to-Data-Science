# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('movies_data.csv')
df.head(5)
# Out:
#                       name                                           overview  \
# 0      Kẻ Đánh Cắp Giấc Mơ  A thief who steals corporate secrets through t...
# 1           Hố Đen Tử Thần  A team of explorers travel through a wormhole ...
# 2  Kỵ Sĩ Bóng Đêm Trỗi Dậy  Eight years after the Joker's reign of anarchy...
# 3        Hành Trình Django  With the help of a German bounty-hunter, a fre...
# 4         Sói Già Phố Wall  Based on the true story of Jordan Belfort, fro...
#
#                                              tagline certificate  runtime  \
# 0                Your mind is the scene of the crime       PG-13    148.0
# 1  Mankind was born on Earth. It was never meant ...         C13    169.0
# 2                                    The Legend Ends       PG-13    164.0
# 3        Life, liberty and the pursuit of vengeance.           R    165.0
# 4                                Earn. Spend. Party.           R    180.0
#
#                                genre  \
# ...

# %% [markdown]
# ## Propose meaningful question

# %% [markdown]
# - How trend nowaday?
# - The most popular languages in modern movies
# - Which languages are rising and which are waning?
# - How genres change between languages
# - Are movie getting longer? (https://stephenfollows.com/are-movies-getting-longer/)

# %%
data = df
netflix_date = data[['release_date']].dropna()
netflix_date['year'] = data['year']
netflix_date['month'] = netflix_date['release_date'].apply(lambda x : x.strftime("%B"))
netflix_date
# month_order = ['01', '02', '03', '04', '05', '06', '07', '08', '09', 'October', 'November', 'December'][::-1]
# df = netflix_date.groupby('year')['month'].value_counts().unstack().fillna(0)[month_order].T
# plt.figure(figsize=(10, 7), dpi=200)
# plt.pcolor(df, cmap='gist_heat_r', edgecolors='white', linewidths=2) # heatmap
# plt.xticks(np.arange(0.5, len(df.columns), 1), df.columns, fontsize=7, fontfamily='serif')
# plt.yticks(np.arange(0.5, len(df.index), 1), df.index, fontsize=7, fontfamily='serif')

# plt.title('Netflix Contents Update', fontsize=12, fontfamily='serif', fontweight='bold', position=(0.20, 1.0+0.02))
# cbar = plt.colorbar()

# cbar.ax.tick_params(labelsize=8) 
# cbar.ax.minorticks_on()
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
type(df['release_date'][0])
# Out:
# str

# %% [markdown]
# Ref: https://stephenfollows.com/languages-most-commonly-used-in-movies/
