# %% [markdown]
# # Data explorations

# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Đọc dữ liệu

# %%
df = pd.read_csv('data.csv', sep='\t')
df.head(5)
# Out:
#                       name                                           overview  \
# 0      Kẻ Đánh Cắp Giấc Mơ  A thief who steals corporate secrets through t...
# 1           Hố Đen Tử Thần  A team of explorers travel through a wormhole ...
# 2  Kỵ Sĩ Bóng Đêm Trỗi Dậy  Eight years after the Joker's reign of anarchy...
# 3        Hành Trình Django  With the help of a German bounty-hunter, a fre...
# 4         Sói Già Phố Wall  Based on the true story of Jordan Belfort, fro...
#
#                                              tagline certificate  runtime  \
# 0                Your mind is the scene of the crime       PG-13    148.0
# 1  Mankind was born on Earth. It was never meant ...         C13    169.0
# 2                                    The Legend Ends       PG-13    164.0
# 3        Life, liberty and the pursuit of vengeance.           R    165.0
# 4                                Earn. Spend. Party.           R    180.0
#
#                        genre  \
# 0  Action, Adventure, Sci-Fi
# 1   Adventure, Drama, Sci-Fi
# 2              Action, Drama
# 3             Drama, Western
# 4   Biography, Comedy, Crime
#
#                                             keywords  imdb_rate  metascore  \
# 0  dream, ambiguous ending, subconscious, mindben...        8.8       74.0
# 1  astronaut, saving the world, space travel, wor...        8.6       74.0
# 2  dc comics, batman character, bruce wayne chara...        8.4       78.0
# 3  racial vengeance, racial violence, slavery, on...        8.4       81.0
# 4  based on true story, stockbroker, female nudit...        8.2       75.0
#
#             director                                              stars  \
# 0  Christopher Nolan  Leonardo DiCaprio, Joseph Gordon-Levitt, Ellio...
# 1  Christopher Nolan  Matthew McConaughey, Anne Hathaway, Jessica Ch...
# 2  Christopher Nolan  Christian Bale, Tom Hardy, Anne Hathaway, Gary...
# 3  Quentin Tarantino  Jamie Foxx, Christoph Waltz, Leonardo DiCaprio...
# 4    Martin Scorsese  Leonardo DiCaprio, Jonah Hill, Margot Robbie, ...
#
#      nvote   gross                       release_date  \
# 0  2344754  292.58      July 16, 2010 (United States)
# 1  1821351  188.02   November 7, 2014 (United States)
# 2  1701579  448.14      July 20, 2012 (United States)
# 3  1549444  162.81  December 25, 2012 (United States)
# 4  1404990  116.90  December 25, 2013 (United States)
#
#                                countries                          language  \
# 0          United States, United Kingdom         English, Japanese, French
# 1  United States, United Kingdom, Canada                           English
# 2          United States, United Kingdom                   English, Arabic
# 3                          United States  English, German, French, Italian
# 4                          United States                   English, French
#
#                                            locations  \
# 0  Fortress Mountain, Kananaskis Country, Alberta...
# 1                                            Iceland
# 2         Mehrangarh Fort, Jodhpur, Rajasthan, India
# 3  Evergreen Plantation, 4677 Highway 18, Edgard,...
# 4                   Portofino, Genoa, Liguria, Italy
#
#                                              company
# 0     Warner Bros., Legendary Entertainment, Syncopy
# 1  Paramount Pictures, Warner Bros., Legendary En...
# 2  Warner Bros., Legendary Entertainment, DC Ente...
# 3           The Weinstein Company, Columbia Pictures
# 4  Red Granite Pictures, Appian Way, Sikelia Prod...

# %% [markdown]
# ### Số dòng và cột

# %%
n_rows, n_cols = df.shape
print(f'Dataset has {n_rows} rows and {n_cols} columns!')
# Out:
# Dataset has 1000 rows and 18 columns!

# %% [markdown]
# Các cột:
# - `name`: Tên phim
# - `overview`: Mô tả tổng quát phim
# - `tagline`: Một văn bản ngắn dùng để làm rõ một ý tưởng hoặc được thiết kế với một dạng hiệu ứng ấn tượng
# - `certificate`: Phân loại phim ( Ví dụ 'R' là phim cấm người dưới 18 tuổi, 'C13' là cấm người dưới 13 tuổi)
# - `runtime`: Thời lượng phim (min)
# - `genre`: Thể loại
# - `keywords`: Từ khóa để dễ dàng tìm kiếm hoặc thể hiện sự tương quan giữa cái bộ phim
# - `imdb_rate`: Số điểm đánh giá từ IMDB
# - `metascore`: Số điểm đánh giá từ Metacritic
# - `director	`: Đạo diễn
# - `stars`: Các ngôi sao của phim
# - `nvote`: Số lượt đánh giá
# - `gross`: Doanh thu của phim (M)
# - `release_date`: Ngày phát hành
# - `countries`: Quốc gia của công ty hoặc chi nhánh quản lý toàn bộ bộ phim
# - `language` : Vì phim phát hành ở nhiều quốc gia nên sẽ có nhiều ngôn ngữ hỗ trợ (bao gồm cả ngôn ngữ gốc)
# - `locations` : Những nơi phim thực hiện
# - `company` : Công ty chịu trách nhiệm sản xuất
#
# Các dòng: Mỗi dòng là thông tin của một bộ phim

# %% [markdown]
# ### Có dòng nào trùng lắp không

# %%
any(df.duplicated())
# Out:
# False

# %% [markdown]
# ### Kiểu dữ liệu:

# %%
pd.DataFrame(pd.concat([df.dtypes, df.isnull().sum()], axis=1)).T.rename(index={0:'type', 1:'null values'})
# Out:
#                name overview tagline certificate  runtime   genre keywords  \
# type         object   object  object      object  float64  object   object
# null values       0        0      72          33        0       0        1
#
#             imdb_rate metascore director   stars  nvote    gross release_date  \
# type          float64   float64   object  object  int64  float64       object
# null values         0        19        0       0      0       95            0
#
#             countries language locations company
# type           object   object    object  object
# null values         0        0        36       0

# %% [markdown]
# Giá trị ở cột `gross` và cột `tagline` bị thiếu khá nhiều. Nguyên nhân `gross` bị thiếu là do nhiều bộ phim không công bố doanh thu. Còn ở cột `tagline`, có lẽ là gì khẩu hiện đã bao gồm trong `overview` nên không xuất hiện lại.

# %% [markdown]
# Các cột `name` `tagline` `overview` `certificate` `keywords` `genre` `director` `release_date` `stars` `language` `locations` `company` có type là `object`. Cần tìm type chính xác của các cột này

# %%
def open_object_dtype(s):
    dtypes = set()
    dtypes = set(s.apply(type))
    return dtypes

# %%
print('name:', open_object_dtype(df['name']))
print('overview:', open_object_dtype(df['overview']))
print('tagline:', open_object_dtype(df['tagline']))
print('keywords:', open_object_dtype(df['keywords']))
print('certificate:', open_object_dtype(df['certificate']))
print('genre:', open_object_dtype(df['genre']))
print('director:', open_object_dtype(df['director']))
print('stars:', open_object_dtype(df['stars']))
print('release_date:', open_object_dtype(df['release_date']))
print('language:', open_object_dtype(df['language']))
print('locations:', open_object_dtype(df['locations']))
print('company:', open_object_dtype(df['company']))
# Out:
# name: {<class 'str'>}
# overview: {<class 'str'>}
# tagline: {<class 'str'>, <class 'float'>}
# keywords: {<class 'str'>, <class 'float'>}
# certificate: {<class 'str'>, <class 'float'>}
# genre: {<class 'str'>}
# director: {<class 'str'>}
# stars: {<class 'str'>}
# release_date: {<class 'str'>}
# language: {<class 'str'>}
# locations: {<class 'str'>, <class 'float'>}
# company: {<class 'str'>}

# %% [markdown]
# Column `keywords` `tagline` `certificate` `locations` có một số giá trị có kiểu `float` do mang giá trị NULL
#
# Các column `keywords` `genre` `director` `stars` `language` `locations` `company`  phải là list tuy nhiên đang có type là 'str'
#
# `release_date` chưa có kiểu dữ liệu là datetime

# %% [markdown]
# #### Chỉnh sửa các column về kiểu dữ liệu phù hợp
#
# * Các column dạng list

# %%
df['keywords'] = df['keywords'].apply(lambda x: x.split(", ") if(type(x) == str) else x)
df['genre'] = df['genre'].apply(lambda x: x.split(", "))
df['director'] = df['director'].apply(lambda x: x.split(", "))
df['stars'] = df['stars'].apply(lambda x: x.split(", "))
df['language'] = df['language'].apply(lambda x: x.split(", "))
df['locations'] = df['locations'].apply(lambda x: x.split(", ") if(type(x) == str) else x)
df['company'] = df['company'].apply(lambda x: x.split(", "))

# %% [markdown]
# * Cột `release_date` có định dạng chưa đúng

# %%
df[['release_date']].sample(n = 10)
# Out:
#                            release_date
# 763     January 1, 2014 (United States)
# 412  September 23, 2016 (United States)
# 465    February 8, 2013 (United States)
# 467    February 6, 2015 (United States)
# 195       July 22, 2011 (United States)
# 662   November 27, 2013 (United States)
# 762   December 21, 2016 (United States)
# 566       July 10, 2020 (United States)
# 911   September 1, 2010 (United States)
# 919        May 25, 2012 (United States)

# %%
def to_datetime(date):
    date = date.split(' (')[0]
    format_ = '%B %d, %Y'
    return dt.datetime.strptime(date, format_).date()

# %%
df['release_date'] = df['release_date'].apply(lambda x: to_datetime(x))
df['release_date'].head(5)
# Out:
# 0    2010-07-16
# 1    2014-11-07
# 2    2012-07-20
# 3    2012-12-25
# 4    2013-12-25
# Name: release_date, dtype: object

# %%
df['year'] = df['release_date'].apply(lambda x: x.year)

# %%
df.head(5)
# Out:
#                       name                                           overview  \
# 0      Kẻ Đánh Cắp Giấc Mơ  A thief who steals corporate secrets through t...
# 1           Hố Đen Tử Thần  A team of explorers travel through a wormhole ...
# 2  Kỵ Sĩ Bóng Đêm Trỗi Dậy  Eight years after the Joker's reign of anarchy...
# 3        Hành Trình Django  With the help of a German bounty-hunter, a fre...
# 4         Sói Già Phố Wall  Based on the true story of Jordan Belfort, fro...
#
#                                              tagline certificate  runtime  \
# 0                Your mind is the scene of the crime       PG-13    148.0
# 1  Mankind was born on Earth. It was never meant ...         C13    169.0
# 2                                    The Legend Ends       PG-13    164.0
# 3        Life, liberty and the pursuit of vengeance.           R    165.0
# 4                                Earn. Spend. Party.           R    180.0
#
#                          genre  \
# 0  [Action, Adventure, Sci-Fi]
# 1   [Adventure, Drama, Sci-Fi]
# 2              [Action, Drama]
# 3             [Drama, Western]
# 4   [Biography, Comedy, Crime]
#
#                                             keywords  imdb_rate  metascore  \
# 0  [dream, ambiguous ending, subconscious, mindbe...        8.8       74.0
# 1  [astronaut, saving the world, space travel, wo...        8.6       74.0
# 2  [dc comics, batman character, bruce wayne char...        8.4       78.0
# 3  [racial vengeance, racial violence, slavery, o...        8.4       81.0
# 4  [based on true story, stockbroker, female nudi...        8.2       75.0
#
#               director                                              stars  \
# 0  [Christopher Nolan]  [Leonardo DiCaprio, Joseph Gordon-Levitt, Elli...
# 1  [Christopher Nolan]  [Matthew McConaughey, Anne Hathaway, Jessica C...
# 2  [Christopher Nolan]  [Christian Bale, Tom Hardy, Anne Hathaway, Gar...
# 3  [Quentin Tarantino]  [Jamie Foxx, Christoph Waltz, Leonardo DiCapri...
# 4    [Martin Scorsese]  [Leonardo DiCaprio, Jonah Hill, Margot Robbie,...
#
#      nvote   gross release_date                              countries  \
# 0  2344754  292.58   2010-07-16          United States, United Kingdom
# 1  1821351  188.02   2014-11-07  United States, United Kingdom, Canada
# 2  1701579  448.14   2012-07-20          United States, United Kingdom
# 3  1549444  162.81   2012-12-25                          United States
# 4  1404990  116.90   2013-12-25                          United States
#
#                              language  \
# 0         [English, Japanese, French]
# 1                           [English]
# 2                   [English, Arabic]
# 3  [English, German, French, Italian]
# 4                   [English, French]
#
#                                            locations  \
# 0  [Fortress Mountain, Kananaskis Country, Albert...
# 1                                          [Iceland]
# 2       [Mehrangarh Fort, Jodhpur, Rajasthan, India]
# 3  [Evergreen Plantation, 4677 Highway 18, Edgard...
# 4                 [Portofino, Genoa, Liguria, Italy]
#
#                                              company  year
# 0   [Warner Bros., Legendary Entertainment, Syncopy]  2010
# 1  [Paramount Pictures, Warner Bros., Legendary E...  2014
# 2  [Warner Bros., Legendary Entertainment, DC Ent...  2012
# 3         [The Weinstein Company, Columbia Pictures]  2012
# 4  [Red Granite Pictures, Appian Way, Sikelia Pro...  2013

# %% [markdown]
# ### Phân bố của từng column

# %% [markdown]
# ### Numeric column

# %%
df[["runtime","release_date", "imdb_rate", "metascore", "nvote", "gross"]].describe().T
# Out:
#             count           mean            std       min        25%  \
# runtime    1000.0     116.014000      19.747855     80.00     102.00
# imdb_rate  1000.0       6.827300       0.820462      1.10       6.30
# metascore   981.0      60.616718      16.498110     18.00      49.00
# nvote      1000.0  261674.923000  224287.456324  88440.00  122446.00
# gross       905.0      99.121370     114.530198      0.01      27.27
#
#                 50%        75%         max
# runtime       114.0     127.00      321.00
# imdb_rate       6.9       7.40        8.80
# metascore      61.0      73.00      100.00
# nvote      179447.0  310666.25  2344754.00
# gross          61.0     128.01      936.66

# %% [markdown]
# ### Categorical column

# %%
def get_cate_col_profiles(df, cate_col):
    missing_ratio = []
    num_diff_vals = []
    diff_vals = []
    for col in cate_col:
        column = df[col].dropna()
        missing_ratio.append( 100 - len(column) / 1000 * 100)
        diff_val = column.to_list()
        if type(column[0]) == list:
            diff_val = pd.Series(sum(diff_val, [])).unique()
        else:
            diff_val = pd.Series(diff_val).unique()
        num_diff_vals.append(len(diff_val))
        diff_vals.append(diff_val)
    profile = pd.DataFrame(([ missing_ratio, num_diff_vals, diff_vals]), columns = cate_col)
    
    index = pd.Series(["missing_ratio%", "num_diff_vals", "diff_vals"])
    profile['Value'] = index
    profile = pd.DataFrame(profile.set_index('Value'))
    
    return profile
cate_col = ['name', 'tagline', 'keywords', 'year', 'overview', 'certificate', 'genre', 'director', 'stars', 'language', 'locations', 'company' ]
cate_col_profiles_df = get_cate_col_profiles(df, cate_col)
cate_col_profiles_df
# Out:
#                                                              name  \
# Value
# missing_ratio%                                                0.0
# num_diff_vals                                                 999
# diff_vals       [Kẻ Đánh Cắp Giấc Mơ, Hố Đen Tử Thần, Kỵ Sĩ Bó...
#
#                                                           tagline  \
# Value
# missing_ratio%                                                7.2
# num_diff_vals                                                 926
# diff_vals       [Your mind is the scene of the crime, Mankind ...
#
#                                                          keywords  \
# Value
# missing_ratio%                                                0.1
# num_diff_vals                                                2911
# diff_vals       [dream, ambiguous ending, subconscious, mindbe...
#
#                                                              year  \
# Value
# missing_ratio%                                                0.0
# num_diff_vals                                                  13
# diff_vals       [2010, 2014, 2012, 2013, 2019, 2018, 2016, 201...
#
#                                                          overview  \
# Value
# missing_ratio%                                                0.0
# num_diff_vals                                                1000
# diff_vals       [A thief who steals corporate secrets through ...
#
#                                                       certificate  \
# Value
# missing_ratio%                                                3.3
# num_diff_vals                                                  10
# diff_vals       [PG-13, C13, R, P, C18, C16, (Banned), PG, G, ...
#
#                                                             genre  \
# Value
# missing_ratio%                                                0.0
# num_diff_vals                                                  20
# diff_vals       [Action, Adventure, Sci-Fi, Drama, Western, Bi...
#
#                                                          director  \
# Value
# missing_ratio%                                                0.0
# num_diff_vals                                                 632
# diff_vals       [Christopher Nolan, Quentin Tarantino, Martin ...
#
#                                                             stars  \
# Value
# missing_ratio%                                                0.0
# num_diff_vals                                                1795
# diff_vals       [Leonardo DiCaprio, Joseph Gordon-Levitt, Elli...
#
#                                                          language  \
# Value
# missing_ratio%                                                0.0
# num_diff_vals                                                 104
# diff_vals       [English, Japanese, French, Arabic, German, It...
#
#                                                         locations  \
# Value
# missing_ratio%                                                3.6
# num_diff_vals                                                1210
# diff_vals       [Fortress Mountain, Kananaskis Country, Albert...
#
#                                                           company
# Value
# missing_ratio%                                                0.0
# num_diff_vals                                                 979
# diff_vals       [Warner Bros., Legendary Entertainment, Syncop...

# %% [markdown]
# # 2. Propose meaningful questions

# %% [markdown]
# - How trend nowaday?
# - The most popular languages in modern movies
# - Which languages are rising and which are waning?
# - How genres change between languages
# - Are movie getting longer? (https://stephenfollows.com/are-movies-getting-longer/)

# %% [markdown]
# ### Preprocess

# %% [markdown]
# Reformat `metascore` to have same meaning with `imdb_score`

# %%
df['metascore'] = df['metascore'].apply(lambda x: x/10)
df['metascore'].head(5)
# Out:
# 0    7.4
# 1    7.4
# 2    7.8
# 3    8.1
# 4    7.5
# Name: metascore, dtype: float64

# %% [markdown]
# ### How trend nowaday?

# %% [markdown]
# I will get top movies of recent year have the highest average score between `imdb_rate` and `metascore`

# %%
data = df

data['average_score'] = data[['imdb_rate','metascore']].mean(axis = 1)

# %% [markdown]
# First we will get top 50 movies have the highest `average_score` in last two years. Then, we get 5 genres appeared the most.

# %%
current_year = 2021
top_50_movies_last_2y = data[(data['year'] == current_year) | (data['year'] == current_year - 1)]

index = top_50_movies_last_2y['average_score'] >= 7.0
top_50_movies_last_2y = top_50_movies_last_2y[index]
top_50_movies_last_2y
# Out:
#                                         name  \
# 39                 Người Nhện: Không Còn Nhà
# 76                             Hành Tinh Cát
# 85                            Thế Chiến 1917
# 116                                    Tenet
# 175                      Không Phải Lúc Chết
#                                                tagline certificate  runtime  \
# 39                           The Multiverse Unleashed.         C13    148.0
# 76                        Beyond fear, destiny awaits.         C13    155.0
# 85                                  Time is the enemy.         C16    119.0
# 116                                      Time Runs Out         C16    150.0
# 175                                       Bond is Back         C16    163.0
# 187                         A Marvel legend will rise.         C13    132.0
# 208                   They're dying to save the world.         C18    132.0
# 231  Everybody has a soul. Joe Gardner is about to ...           P    100.0
# 382                    What You Can't See Can Hurt You         C18    124.0
# 384                              Silence is Not Enough         C16     97.0
# 386                                                NaN         C18     94.0
# 398                     Magical House. Magical Family.           P    102.0
# 436                                                NaN         NaN    164.0
# 506           In 1968, democracy refused to back down.         C18    129.0
# 517                         What it means to be a man.         C16    126.0
# 519             This Christmas. Plan to make them pay.         C18    113.0
# 550                 Prepare for an unforgettable trip.          PG     95.0
# 557     Surviving America in the Twenty-First Century.           R    107.0
# 566                      Live Like There's No Tomorrow         C18     90.0
# 568                                                NaN         NaN    117.0
# 580  The true story of a woman who defied a nation ...           R    152.0
# 591                             Nothing is as it seems       PG-13     97.0
# 603                                                NaN           P    107.0
# 632                                                NaN         C18    150.0
# 689                 Every family has its own language.       PG-13    111.0
# 697                                                NaN         NaN    101.0
# 712  Music was his world. Then silence revealed a n...           R    120.0
# 750                                                NaN           R    107.0
# 751                                                NaN         NaN    135.0
# 779                               A rebel with an idea         NaN    153.0
# 790                                                NaN           R    133.0
# 798            Venus, Serena and a plan for greatness.       PG-13    144.0
# 823  Prepare to get weird, cause the world depends ...         C13    114.0
# 842    How much time do we have to do something great?         C13    120.0
# 883  When honor was everything. When courage made k...           R    130.0
# 930                                An American Musical       PG-13    160.0
# 952                                                NaN           R    122.0
#
#                               genre  \
# 39     [Action, Adventure, Fantasy]
# 76       [Action, Adventure, Drama]
# 85             [Action, Drama, War]
# 116      [Action, Sci-Fi, Thriller]
# 175   [Action, Adventure, Thriller]
# 187    [Action, Adventure, Fantasy]
# 208     [Action, Adventure, Comedy]
# 231  [Animation, Adventure, Comedy]
# 382        [Drama, Horror, Mystery]
# 384         [Drama, Horror, Sci-Fi]
# 386      [Horror, Sci-Fi, Thriller]
# 398     [Animation, Comedy, Family]
# 436         [Crime, Drama, Mystery]
# 506      [Drama, History, Thriller]
# 517       [Drama, Romance, Western]
# 519         [Crime, Drama, Mystery]
# 550  [Animation, Adventure, Comedy]
# 557                         [Drama]
# 566      [Comedy, Fantasy, Mystery]
# 568                 [Comedy, Drama]
# 580        [Action, Drama, History]
# 591                [Drama, Mystery]
# 603  [Animation, Action, Adventure]
# 632        [Crime, Drama, Thriller]
# 689          [Comedy, Drama, Music]
# 697        [Comedy, Drama, Romance]
# 712                  [Drama, Music]
# 750        [Comedy, Drama, Romance]
# 751      [Action, Biography, Drama]
# 779                         [Drama]
# 790        [Comedy, Drama, Romance]
# 798       [Biography, Drama, Sport]
# 823  [Animation, Adventure, Comedy]
# 842      [Biography, Comedy, Drama]
# 883     [Adventure, Drama, Fantasy]
# 930     [Biography, Drama, History]
# 952                [Drama, Romance]
#
#                                               keywords  imdb_rate  metascore  \
# 39   [spider man character, marvel cinematic univer...        8.3        7.1
# 76   [mother son relationship, mind control, future...        8.0        7.4
# 85   [world war one, year 1917, no man's land, long...        8.2        7.8
# 116  [time paradox, time reversal, car chase, espio...        7.3        6.9
# 175  [official james bond series, james bond charac...        7.3        6.8
# 187  [superhero, dragon, martial arts, marvel comic...        7.4        7.1
# 208  [superheroine, giant monster, superhero, based...        7.2        7.2
# 231      [jazz, purpose, cat, jazz musician, musician]        8.0        8.3
# 382  [domestic abuse, psychological abuse, invisibi...        7.1        7.2
# 384  [sequel, post apocalypse, oxygen tank, alien, ...        7.2        7.1
# 386    [hunger, prison, cannibalism, platform, inmate]        7.0        7.3
# 398   [colombia, magic, magical house, candle, disney]        7.2        7.5
# 436                                           [lawyer]        8.8        NaN
# 506  [riot, protesting vietnam war, protest march, ...        7.7        7.6
# 517  [repressed homosexuality, animal cruelty, bull...        6.8        8.9
# 519  [revenge, bachelor party, 30th birthday, rape,...        7.5        7.3
# 550  [friendship, coming of age, shapeshifter, ocea...        7.4        7.1
# 557  [living in a van, van, nomad, economic recessi...        7.3        9.1
# 566  [time loop, stuck in a time loop, day repeats ...        7.4        8.3
# 568  [drinking, teacher, friendship, restaurant, dr...        7.7        7.9
# 580  [14th century, duel, battle, husband wife rela...        7.4        6.7
# 591  [dementia, alzheimer's disease, memory loss, b...        8.2        8.8
# 603  [dragon, baby, sympathetic monster, turned to ...        7.3        7.4
# 632  [neo noir, mentalist, male frontal nudity, mal...        7.0        7.0
# 689  [sign language, remake of french film, deaf pa...        8.0        7.2
# 697  [love, cancer, cancer support group, incomplet...        8.1        NaN
# 712  [drug addict, deaf community, musician, anger,...        7.7        8.2
# 750  [journalist, woman poses nude for a painting, ...        7.1        7.4
# 751  [soldier, kargil war, indian army, pakistan, i...        8.4        NaN
# 779  [struggle, airplane, two word title, bike, run...        8.7        NaN
# 790  [jewish, age difference, coming of age, year 1...        7.2        9.0
# 798  [tennis player, compton, father, based on real...        7.5        7.6
# 823   [robot, road trip, dog, furby, family road trip]        7.6        8.1
# 842  [30th birthday, 29 year old man, composer, the...        7.5        7.4
# 883  [medieval knight, sir gawain character, myth, ...        6.6        8.5
# 930  [hip hop, american history, alexander hamilton...        8.4        8.9
# 952  [lesbian relationship, portrait painting, arra...        8.1        9.5
#
#                                               director  \
# 39                                         [Jon Watts]
# 76                                  [Denis Villeneuve]
# 85                                        [Sam Mendes]
# 116                                [Christopher Nolan]
# 175                               [Cary Joji Fukunaga]
# 187                            [Destin Daniel Cretton]
# 208                                       [James Gunn]
# 231                         [Pete Docter, Kemp Powers]
# 382                                   [Leigh Whannell]
# 384                                   [John Krasinski]
# 386                           [Galder Gaztelu-Urrutia]
# 398   [Jared Bush, Byron Howard, Charise Castro Smith]
# 436                                    [T.J. Gnanavel]
# 506                                     [Aaron Sorkin]
# 517                                     [Jane Campion]
# 519                                  [Emerald Fennell]
# 550                                  [Enrico Casarosa]
# 557                                       [Chloé Zhao]
# 557  [Cor Cordium Productions, Hear/Say Productions...  2021           8.20
# 566  [Limelight, Sun Entertainment Culture, The Lon...  2020           7.85
# 568  [Zentropa Entertainments, Film i Väst, Zentrop...  2020           7.80
# 580  [20th Century Studios, Pearl Street Films, Sco...  2021           7.05
# 591           [Les Films du Cru, Film4, Orange Studio]  2021           8.50
# 603  [Walt Disney Animation Studios, Walt Disney Pi...  2021           7.35
# 632  [Searchlight Pictures, Searchlight Pictures, D...  2021           7.00
# 689  [Apple Original Films, Vendôme Pictures, Pathé...  2021           7.60
# 697                                 [Fox STAR Studios]  2020           8.10
# 712            [Caviar, Flat 7 Productions, Ward Four]  2020           7.95
# 750  [American Empirical Pictures, Indian Paintbrus...  2021           7.25
# 751                               [Dharma Productions]  2021           8.40
# 779  [2D Entertainment, Goldmines Telefilms, Sikhya...  2020           8.70
# 790  [Metro-Goldwyn-Mayer (MGM), Focus Features, Br...  2021           8.10
# 798  [Warner Bros., Star Thrower Entertainment, Wes...  2021           7.55
# 823  [Sony Pictures Animation, Lord Miller, Columbi...  2021           7.85
# 842  [5000 Broadway Productions, Imagine Entertainm...  2021           7.45
# 883                   [Sailor Bear, BRON Studios, A24]  2021           7.55
# 930  [Walt Disney Pictures, 5000 Broadway Productio...  2020           8.65
# 952  [Lilies Films, Arte France Cinéma, Hold Up Films]  2020           8.80

# %%
genres = top_50_movies_last_2y['genre'].explode()
genres_count = genres.value_counts()

# %%
plt.figure(figsize=(15,5))
#plt.hist(genres_count,bins=[0, 5, 6, 7, 8, 9, 10])
barlist = genres_count.plot.bar()
barlist.patches[0].set_color('b')

# %% [markdown]
# 5 genres appered the most are *Drama*, *Comedy*, *Action*, *Adventure*, *Romance*. Next step we will analyze the appearion of 5 genres through the years.

# %% [markdown]
# Action

# %%
def get_top_genre(genre):
    #Get top 50 movies each year and drop movie not in 'Action' genre
    top_movies_in_genre = data.sort_values(['year','average_score'],ascending=False).groupby('year').head(50).loc[data.apply(lambda x: genre in x.genre, axis=1)]
    return top_movies_in_genre.groupby('year').size()

drama_ = get_top_genre("Drama")
comedy_ = get_top_genre("Comedy")
action_ = get_top_genre("Action")
adventure_ = get_top_genre("Adventure")
romance_ = get_top_genre("Romance")

# %%
df_top_genre = pd.concat({"Drama": drama_,
                         "Comedy": comedy_,
                         "Action": action_,
                         "Adventure": adventure_,
                         "Romance": romance_},
                         axis=1, levels=None)
df_top_genre
# Out:
#       Drama  Comedy  Action  Adventure  Romance
# year
# 2010     28      17      20         12        9
# 2011     33      12      16         14       10
# 2012     28      17      17         17        7
# 2013     31      16      12         12        6
# 2014     32      12      18         15        4
# 2015     29      14      21         18        4
# 2016     31      14      15         14        4
# 2017     32      11      20         14        2
# 2018     30      19      14         15        6
# 2019     29      18      16         17        3
# 2020     16      13      18          8        3
# 2021     25      14      23         20        3

# %%
# plt.figure(figsize=(15,5))
# plt.xticks(range(2010,2022))
# plt.plot(df_top_genre)
# plt.show()
sns.set(rc={'figure.figsize':(15,5)})
sns.lineplot(data=df_top_genre,marker=True)
plt.show()
